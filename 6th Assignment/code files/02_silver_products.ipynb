# %%
from pyspark.sql.functions import col

# %% [markdown]
# # Paths

# %%
bronze_products_path = "dbfs:/Volumes/workspace/retail/raw/bronze/products/products_master.csv"

# %% [markdown]
# # Read Bronze Products (CSV)

# %%
products_df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv(bronze_products_path)
)

# %% [markdown]
# # Basic cleansing

# %%
silver_products_df = (
    products_df
    .dropDuplicates(["product_id"])
    .filter(col("product_id").isNotNull())
)

# %% [markdown]
# # Write Silver Products (overwrite snapshot)

# %%
(
    silver_products_df.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("workspace.retail.silver_products")
)

# %%
print("Silver Products table created successfully")
# Out:
# Silver Products table created successfully
