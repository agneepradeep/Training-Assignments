-- %%
USE taxi_etl_db;

-- %%
-- 2. Compare Bronze vs Silver (quality rule)
SELECT
  (SELECT COUNT(*) FROM taxi_bronze)          AS bronze_count,
  (SELECT COUNT(*) FROM taxi_silver_clean)    AS silver_clean_count;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>bronze_count</th><th>silver_clean_count</th></tr></thead><tbody><tr><td>500</td><td>467</td></tr></tbody></table></div>

-- %%
-- 3. Confirm there are no bad distances in Silver
SELECT COUNT(*) AS bad_trips_in_silver
FROM taxi_silver_clean
WHERE trip_distance <= 0 OR trip_distance IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>bad_trips_in_silver</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

-- %%
SHOW TABLES;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>taxi_etl_db</td><td>taxi_bronze</td><td>false</td></tr><tr><td>taxi_etl_db</td><td>taxi_gold_top3_highest_fares</td><td>false</td></tr><tr><td>taxi_etl_db</td><td>taxi_silver_clean</td><td>false</td></tr><tr><td>taxi_etl_db</td><td>taxi_silver_suspicious_rides</td><td>false</td></tr><tr><td>taxi_etl_db</td><td>taxi_silver_weekly_aggregates</td><td>false</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) FROM taxi_bronze;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>500</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) FROM taxi_silver_clean;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>467</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) FROM taxi_silver_suspicious_rides;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>467</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) FROM taxi_silver_weekly_aggregates;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

-- %%
SELECT * FROM taxi_gold_top3_highest_fares;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
